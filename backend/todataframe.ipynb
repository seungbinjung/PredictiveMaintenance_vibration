# %%
import pandas as pd
import numpy as np

# %%
import sys
from pathlib import Path
import os

# Jupyter 노트북에서는 __file__이 없으므로 현재 작업 디렉토리 기반으로 경로 설정
# 노트북이 backend 디렉토리에 있으므로, 상위 디렉토리(caps)를 프로젝트 루트로 설정
PROJECT_ROOT = Path(os.getcwd()).resolve().parent  # backend -> caps
EXTRA_PATHS = [
    str(PROJECT_ROOT),                    # caps 루트
    str(PROJECT_ROOT / "backend"),        # backend 디렉토리
#     str(PROJECT_ROOT / "ByteTrack"),        # ByteTrack 직접 참조가 필요한 경우
#     str(PROJECT_ROOT / "deep-person-reid-master"),  # 필요한 경우만
#     str(PROJECT_ROOT / "app" / "models" / "mapping"),   # point_transformer 경로 수정
]

for p in EXTRA_PATHS:
    if p not in sys.path:
        sys.path.insert(0, p)
        
print(f"프로젝트 루트: {PROJECT_ROOT}")
print(f"추가된 경로: {EXTRA_PATHS}")
# Out:
# 프로젝트 루트: /Users/jeongseungbin/Desktop/caps
# 추가된 경로: ['/Users/jeongseungbin/Desktop/caps', '/Users/jeongseungbin/Desktop/caps/backend']

# %%
cd ..
# Out:
# /Users/jeongseungbin/Desktop/caps

# %%
df = pd.read_parquet("test_dataset0.parquet")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          0.0   0.00025    0.0005   0.00075     0.001   0.00125    0.0015  \
# 0  -0.014008 -0.017333  0.006403 -0.002804  0.002442  0.006760 -0.006655
# 1   0.002495  0.005999  0.003348  0.007982  0.009915  0.005232  0.005688
# 2  -0.015848 -0.018464  0.003476 -0.009597 -0.005623  0.007573 -0.016222
# 3   0.014736  0.010680  0.012585  0.016348  0.012289  0.008127  0.009071
# 4  -0.005500 -0.013463 -0.011433 -0.014135 -0.016219 -0.010746 -0.007531
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.000548  0.013220  0.005666 -0.007071  0.000576  0.003161 -0.000211
# 96 -0.003707  0.004584  0.002831 -0.001429 -0.004122 -0.012973 -0.007247
# 97 -0.019368 -0.014298 -0.014234 -0.005713 -0.010156 -0.016867 -0.002609
# 98 -0.016192 -0.008046 -0.009129 -0.020338 -0.010224 -0.009325 -0.018575
# 99 -0.010043 -0.024673 -0.004266  0.001390 -0.015974 -0.008867 -0.009841
#
#      0.00175     0.002   0.00225  ...   2.99775     2.998   2.99825    2.9985  \
# 0   0.001196  0.003749 -0.004444  ... -0.000567 -0.000153 -0.009571 -0.000067
# 1   0.017478  0.013383  0.008459  ...  0.007692 -0.012180  0.011355  0.008595
# 2  -0.008122  0.000877 -0.021121  ... -0.008010 -0.016047 -0.001228 -0.005462
# 3   0.002384  0.004463  0.012310  ...  0.000811  0.005169  0.008669  0.000169
# 4  -0.008451 -0.006861 -0.002182  ... -0.005048 -0.001952 -0.007523 -0.013254
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  0.006849  0.004082 -0.008216  ...  0.013501  0.012457 -0.001792  0.000519
# 96 -0.002480 -0.017141 -0.016769  ... -0.001724  0.001725 -0.000436  0.007468
# 97 -0.007375 -0.020799 -0.015476  ... -0.017700 -0.016785 -0.011464 -0.013581
# 98  0.003272  0.003504 -0.015040  ... -0.011011 -0.019486 -0.004048 -0.007836
# 99 -0.020021 -0.012351 -0.015183  ... -0.006712 -0.022364 -0.016293 -0.006143
#
#      2.99875     2.999   2.99925    2.9995   2.99975  Label_No
# 0   0.008216 -0.006766 -0.001681  0.015646  0.007652       0.0
# 1  -0.007489  0.007237  0.001939 -0.008432  0.007958       0.0
# 2  -0.003330  0.009472 -0.001400 -0.004578  0.004140       0.0
# 3   0.007775  0.008169 -0.010616 -0.007014  0.008075       0.0
# 4  -0.010520 -0.014908 -0.018048 -0.013167  0.000388       0.0
# ..       ...       ...       ...       ...       ...       ...
# 95 -0.001074 -0.010256 -0.002019  0.005028 -0.000749       0.0
# 96 -0.004668 -0.011596 -0.004366 -0.004257 -0.015558       0.0
# 97 -0.010100 -0.008177 -0.008810  0.000647 -0.005806       0.0
# 98 -0.022445 -0.015824 -0.012203 -0.028628 -0.014560       0.0
# 99 -0.026061 -0.012270 -0.000259 -0.007270  0.002661       0.0
#
# [100 rows x 12001 columns]

# %%
testmessage=np.array(df.iloc[0])
