# %%
# !pip install fastapi uvicorn pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("ngrok에서 발급받은 토큰 여기 입력")

# %%
public_url = ngrok.connect(5000)
public_url
# Out:
# <NgrokTunnel: "https://noncensurable-unrebelliously-gracia.ngrok-free.dev" -> "http://localhost:5000">

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 구글드라이브에서 현재폳더 위치로 수정하시면 됩니다.

# %%
cd drive/MyDrive/예지보전_dataset/colab
# Out:
# /content/drive/.shortcut-targets-by-id/1qh3jzitGUW0lb7c-S6nTb5IS7ThRIU5U/예지보전_dataset/분석서버

# %%
import colab_api

# %%
# !uvicorn colab_api:app --host 0.0.0.0 --port 5000
# Out:
# 2025-11-30 12:54:21.811877: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764507261.834226    6114 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764507261.840678    6114 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764507261.857387    6114 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
